# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 737

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | ponta do sol
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | biskamzha
# Processing Record 5 of Set 1 | chuy
# Processing Record 6 of Set 1 | bonaventure
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | turka
# Processing Record 11 of Set 1 | constitucion
# Processing Record 12 of Set 1 | kirakira
# Processing Record 13 of Set 1 | skibbereen
# Processing Record 14 of Set 1 | kupang
# Processing Record 15 of Set 1 | port elizabeth
# Processing Record 16 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | abyek
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | aykhal
# Processing Record 21 of Set 1 | dubbo
# Processing Record 22 of Set 1 | laguna
# Processing Record 23 of Set 1 | methven
# Processing Record 24 of Set 1 | port blair
# Processing Record 25 of Set 1 | kollo
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | carnarvon
# Processing Record 28 of Set 1 | puri
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | saskylakh
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | repnoye
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | miraflores
# Processing Record 35 of Set 1 | fortuna
# Processing Record 36 of Set 1 | litoral del san juan
# City not found. Skipping...
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | dillon
# Processing Record 39 of Set 1 | atar
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 1 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 43 of Set 1 | torbay
# Processing Record 44 of Set 1 | guerrero negro
# Processing Record 45 of Set 1 | shubarshi
# Processing Record 46 of Set 1 | faanui
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | tabuk
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | alofi
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | kargasok
# Processing Record 5 of Set 2 | carutapera
# Processing Record 6 of Set 2 | beringovskiy
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | bhinmal
# Processing Record 9 of Set 2 | vardo
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | oriximina
# Processing Record 12 of Set 2 | parrita
# Processing Record 13 of Set 2 | rikitea
# Processing Record 14 of Set 2 | perelyub
# Processing Record 15 of Set 2 | saldanha
# Processing Record 16 of Set 2 | maragogi
# Processing Record 17 of Set 2 | lavrentiya
# Processing Record 18 of Set 2 | souillac
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 21 of Set 2 | fairbanks
# Processing Record 22 of Set 2 | uusikaupunki
# Processing Record 23 of Set 2 | touros
# Processing Record 24 of Set 2 | axim
# Processing Record 25 of Set 2 | ponta delgada
# Processing Record 26 of Set 2 | inhambane
# Processing Record 27 of Set 2 | punta arenas
# Processing Record 28 of Set 2 | ozernovskiy
# Processing Record 29 of Set 2 | upernavik
# Processing Record 30 of Set 2 | qaqortoq
# Processing Record 31 of Set 2 | khandyga
# Processing Record 32 of Set 2 | sitka
# Processing Record 33 of Set 2 | severo-kurilsk
# Processing Record 34 of Set 2 | sinnamary
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | yar-sale
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | chifeng
# Processing Record 40 of Set 2 | sao filipe
# Processing Record 41 of Set 2 | shingu
# Processing Record 42 of Set 2 | dingle
# Processing Record 43 of Set 2 | bilibino
# Processing Record 44 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 2 | narsaq
# Processing Record 46 of Set 2 | ejura
# Processing Record 47 of Set 2 | baculin
# Processing Record 48 of Set 2 | hofn
# Processing Record 49 of Set 2 | vila franca do campo
# Processing Record 50 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 3 | yangambi
# Processing Record 2 of Set 3 | port hardy
# Processing Record 3 of Set 3 | buldana
# Processing Record 4 of Set 3 | dunmore town
# Processing Record 5 of Set 3 | myanaung
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | cherskiy
# Processing Record 8 of Set 3 | puerto ayora
# Processing Record 9 of Set 3 | charters towers
# Processing Record 10 of Set 3 | hambantota
# Processing Record 11 of Set 3 | smithers
# Processing Record 12 of Set 3 | rambouillet
# Processing Record 13 of Set 3 | mar del plata
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | grindavik
# Processing Record 16 of Set 3 | nikolskoye
# Processing Record 17 of Set 3 | wasilla
# Processing Record 18 of Set 3 | opuwo
# Processing Record 19 of Set 3 | gizo
# Processing Record 20 of Set 3 | kruisfontein
# Processing Record 21 of Set 3 | east london
# Processing Record 22 of Set 3 | bochnia
# Processing Record 23 of Set 3 | karratha
# Processing Record 24 of Set 3 | labuan
# Processing Record 25 of Set 3 | broome
# Processing Record 26 of Set 3 | puerto quijarro
# Processing Record 27 of Set 3 | brae
# Processing Record 28 of Set 3 | puerto rondon
# Processing Record 29 of Set 3 | lamu
# Processing Record 30 of Set 3 | yaitepec
# City not found. Skipping...
# Processing Record 31 of Set 3 | juneau
# Processing Record 32 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 3 | isangel
# Processing Record 34 of Set 3 | roros
# Processing Record 35 of Set 3 | pinega
# Processing Record 36 of Set 3 | doba
# Processing Record 37 of Set 3 | necochea
# Processing Record 38 of Set 3 | norman wells
# Processing Record 39 of Set 3 | hithadhoo
# Processing Record 40 of Set 3 | saint-philippe
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | ancud
# Processing Record 43 of Set 3 | chapais
# Processing Record 44 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 3 | hare bay
# Processing Record 46 of Set 3 | tiksi
# Processing Record 47 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 50 of Set 3 | pong
# Processing Record 1 of Set 4 | thinadhoo
# Processing Record 2 of Set 4 | soria
# Processing Record 3 of Set 4 | lorengau
# Processing Record 4 of Set 4 | margate
# Processing Record 5 of Set 4 | clyde river
# Processing Record 6 of Set 4 | sarkand
# Processing Record 7 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 8 of Set 4 | nyurba
# Processing Record 9 of Set 4 | mahebourg
# Processing Record 10 of Set 4 | tasiilaq
# Processing Record 11 of Set 4 | new norfolk
# Processing Record 12 of Set 4 | whitecourt
# Processing Record 13 of Set 4 | luderitz
# Processing Record 14 of Set 4 | samarinda
# Processing Record 15 of Set 4 | tignere
# Processing Record 16 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 4 | preobrazheniye
# Processing Record 18 of Set 4 | san patricio
# Processing Record 19 of Set 4 | akyab
# Processing Record 20 of Set 4 | praia
# Processing Record 21 of Set 4 | wadi musa
# Processing Record 22 of Set 4 | kristiinankaupunki
# Processing Record 23 of Set 4 | hobyo
# Processing Record 24 of Set 4 | wenatchee
# Processing Record 25 of Set 4 | esperance
# Processing Record 26 of Set 4 | sedkyrkeshch
# Processing Record 27 of Set 4 | matadi
# Processing Record 28 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 4 | nhulunbuy
# Processing Record 30 of Set 4 | santarem
# Processing Record 31 of Set 4 | dikson
# Processing Record 32 of Set 4 | srednekolymsk
# Processing Record 33 of Set 4 | omboue
# Processing Record 34 of Set 4 | portland
# Processing Record 35 of Set 4 | cayenne
# Processing Record 36 of Set 4 | avarua
# Processing Record 37 of Set 4 | ixtapa
# Processing Record 38 of Set 4 | grand gaube
# Processing Record 39 of Set 4 | vestmannaeyjar
# Processing Record 40 of Set 4 | khvatovka
# Processing Record 41 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 42 of Set 4 | tuatapere
# Processing Record 43 of Set 4 | namatanai
# Processing Record 44 of Set 4 | kidal
# Processing Record 45 of Set 4 | langfang
# Processing Record 46 of Set 4 | puerto escondido
# Processing Record 47 of Set 4 | atuona
# Processing Record 48 of Set 4 | tuktoyaktuk
# Processing Record 49 of Set 4 | bambous virieux
# Processing Record 50 of Set 4 | moerai
# Processing Record 1 of Set 5 | college
# Processing Record 2 of Set 5 | natal
# Processing Record 3 of Set 5 | avera
# Processing Record 4 of Set 5 | rusera
# Processing Record 5 of Set 5 | khatanga
# Processing Record 6 of Set 5 | parati
# Processing Record 7 of Set 5 | napa
# Processing Record 8 of Set 5 | zruc nad sazavou
# Processing Record 9 of Set 5 | santa rosa
# Processing Record 10 of Set 5 | manta
# Processing Record 11 of Set 5 | humberto de campos
# Processing Record 12 of Set 5 | ayios matthaios
# City not found. Skipping...
# Processing Record 13 of Set 5 | hoopstad
# Processing Record 14 of Set 5 | vanderhoof
# Processing Record 15 of Set 5 | shimoda
# Processing Record 16 of Set 5 | shenjiamen
# Processing Record 17 of Set 5 | harper
# Processing Record 18 of Set 5 | chokurdakh
# Processing Record 19 of Set 5 | nybro
# Processing Record 20 of Set 5 | iqaluit
# Processing Record 21 of Set 5 | najran
# Processing Record 22 of Set 5 | eyrarbakki
# Processing Record 23 of Set 5 | lompoc
# Processing Record 24 of Set 5 | pimenta bueno
# Processing Record 25 of Set 5 | airai
# Processing Record 26 of Set 5 | vao
# Processing Record 27 of Set 5 | pisco
# Processing Record 28 of Set 5 | palmer
# Processing Record 29 of Set 5 | mooresville
# Processing Record 30 of Set 5 | sao felix do xingu
# Processing Record 31 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 32 of Set 5 | broken hill
# Processing Record 33 of Set 5 | yumaguzino
# Processing Record 34 of Set 5 | maun
# Processing Record 35 of Set 5 | requena
# Processing Record 36 of Set 5 | sisimiut
# Processing Record 37 of Set 5 | samur
# Processing Record 38 of Set 5 | hay river
# Processing Record 39 of Set 5 | cidreira
# Processing Record 40 of Set 5 | urumqi
# Processing Record 41 of Set 5 | meiktila
# Processing Record 42 of Set 5 | aripuana
# Processing Record 43 of Set 5 | monrovia
# Processing Record 44 of Set 5 | arraial do cabo
# Processing Record 45 of Set 5 | puerto leguizamo
# Processing Record 46 of Set 5 | talnakh
# Processing Record 47 of Set 5 | anadyr
# Processing Record 48 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 5 | masindi
# Processing Record 50 of Set 5 | provideniya
# Processing Record 1 of Set 6 | port moresby
# Processing Record 2 of Set 6 | bathsheba
# Processing Record 3 of Set 6 | zorritos
# Processing Record 4 of Set 6 | akhtanizovskaya
# Processing Record 5 of Set 6 | pijijiapan
# Processing Record 6 of Set 6 | khash
# Processing Record 7 of Set 6 | hilo
# Processing Record 8 of Set 6 | fort nelson
# Processing Record 9 of Set 6 | arman
# Processing Record 10 of Set 6 | sokolka
# Processing Record 11 of Set 6 | berlevag
# Processing Record 12 of Set 6 | maymyo
# Processing Record 13 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 6 | tabou
# Processing Record 15 of Set 6 | zeya
# Processing Record 16 of Set 6 | pacific grove
# Processing Record 17 of Set 6 | hoquiam
# Processing Record 18 of Set 6 | lakatoro
# Processing Record 19 of Set 6 | kahului
# Processing Record 20 of Set 6 | vestmanna
# Processing Record 21 of Set 6 | treinta y tres
# Processing Record 22 of Set 6 | wladyslawowo
# Processing Record 23 of Set 6 | brodick
# Processing Record 24 of Set 6 | makung
# City not found. Skipping...
# Processing Record 25 of Set 6 | ambelokipoi
# Processing Record 26 of Set 6 | nanortalik
# Processing Record 27 of Set 6 | tucuman
# Processing Record 28 of Set 6 | skjervoy
# Processing Record 29 of Set 6 | yantal
# Processing Record 30 of Set 6 | namibe
# Processing Record 31 of Set 6 | richards bay
# Processing Record 32 of Set 6 | dawlatabad
# Processing Record 33 of Set 6 | hualmay
# Processing Record 34 of Set 6 | arlit
# Processing Record 35 of Set 6 | acapulco
# Processing Record 36 of Set 6 | huarmey
# Processing Record 37 of Set 6 | namie
# Processing Record 38 of Set 6 | alamogordo
# Processing Record 39 of Set 6 | villa bruzual
# Processing Record 40 of Set 6 | yilan
# Processing Record 41 of Set 6 | ostrovnoy
# Processing Record 42 of Set 6 | antofagasta
# Processing Record 43 of Set 6 | nome
# Processing Record 44 of Set 6 | doha
# Processing Record 45 of Set 6 | okhotsk
# Processing Record 46 of Set 6 | poum
# Processing Record 47 of Set 6 | valera
# Processing Record 48 of Set 6 | lobito
# Processing Record 49 of Set 6 | noumea
# Processing Record 50 of Set 6 | kaeo
# Processing Record 1 of Set 7 | sayville
# Processing Record 2 of Set 7 | bandarbeyla
# Processing Record 3 of Set 7 | rawson
# Processing Record 4 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 7 | xining
# Processing Record 6 of Set 7 | tomatlan
# Processing Record 7 of Set 7 | bardiyah
# Processing Record 8 of Set 7 | belmonte
# Processing Record 9 of Set 7 | cooma
# Processing Record 10 of Set 7 | victoria
# Processing Record 11 of Set 7 | bud
# Processing Record 12 of Set 7 | bermejo
# Processing Record 13 of Set 7 | umm lajj
# Processing Record 14 of Set 7 | saint george
# Processing Record 15 of Set 7 | los llanos de aridane
# Processing Record 16 of Set 7 | tutoia
# Processing Record 17 of Set 7 | mecca
# Processing Record 18 of Set 7 | trairi
# Processing Record 19 of Set 7 | lebu
# Processing Record 20 of Set 7 | san quintin
# Processing Record 21 of Set 7 | abu dhabi
# Processing Record 22 of Set 7 | zhigansk
# Processing Record 23 of Set 7 | panaba
# Processing Record 24 of Set 7 | ushtobe
# Processing Record 25 of Set 7 | itarema
# Processing Record 26 of Set 7 | ankazoabo
# Processing Record 27 of Set 7 | la presa
# Processing Record 28 of Set 7 | erdenet
# Processing Record 29 of Set 7 | padang
# Processing Record 30 of Set 7 | samarai
# Processing Record 31 of Set 7 | nampula
# Processing Record 32 of Set 7 | paamiut
# Processing Record 33 of Set 7 | oranjemund
# Processing Record 34 of Set 7 | awash
# Processing Record 35 of Set 7 | san cristobal
# Processing Record 36 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 37 of Set 7 | vinh
# Processing Record 38 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 7 | ullapool
# Processing Record 40 of Set 7 | ilulissat
# Processing Record 41 of Set 7 | saint anthony
# Processing Record 42 of Set 7 | mitu
# Processing Record 43 of Set 7 | saint-leu
# Processing Record 44 of Set 7 | moose factory
# Processing Record 45 of Set 7 | geraldton
# Processing Record 46 of Set 7 | liverpool
# Processing Record 47 of Set 7 | ust-ilimsk
# Processing Record 48 of Set 7 | sur
# Processing Record 49 of Set 7 | cap malheureux
# Processing Record 50 of Set 7 | chemin grenier
# Processing Record 1 of Set 8 | jacareacanga
# Processing Record 2 of Set 8 | codrington
# Processing Record 3 of Set 8 | novoagansk
# Processing Record 4 of Set 8 | ibate
# Processing Record 5 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 6 of Set 8 | balad
# Processing Record 7 of Set 8 | caravelas
# Processing Record 8 of Set 8 | rognedino
# Processing Record 9 of Set 8 | gunjur
# Processing Record 10 of Set 8 | tual
# Processing Record 11 of Set 8 | lucapa
# Processing Record 12 of Set 8 | ingham
# Processing Record 13 of Set 8 | vanimo
# Processing Record 14 of Set 8 | great falls
# Processing Record 15 of Set 8 | vuktyl
# Processing Record 16 of Set 8 | havre-saint-pierre
# Processing Record 17 of Set 8 | bethel
# Processing Record 18 of Set 8 | mount gambier
# Processing Record 19 of Set 8 | maningrida
# Processing Record 20 of Set 8 | kungsbacka
# Processing Record 21 of Set 8 | chekmagush
# Processing Record 22 of Set 8 | ketchikan
# Processing Record 23 of Set 8 | fiche
# Processing Record 24 of Set 8 | pirganj
# Processing Record 25 of Set 8 | chongoyape
# Processing Record 26 of Set 8 | ahipara
# Processing Record 27 of Set 8 | santa vitoria do palmar
# Processing Record 28 of Set 8 | thornton
# Processing Record 29 of Set 8 | comodoro rivadavia
# Processing Record 30 of Set 8 | yerbogachen
# Processing Record 31 of Set 8 | sassandra
# Processing Record 32 of Set 8 | bondo
# Processing Record 33 of Set 8 | lazaro cardenas
# Processing Record 34 of Set 8 | zhongshu
# Processing Record 35 of Set 8 | cam ranh
# Processing Record 36 of Set 8 | biak
# Processing Record 37 of Set 8 | mezen
# Processing Record 38 of Set 8 | itaituba
# Processing Record 39 of Set 8 | cove
# Processing Record 40 of Set 8 | mandalgovi
# Processing Record 41 of Set 8 | coahuayana
# Processing Record 42 of Set 8 | envira
# Processing Record 43 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 8 | megion
# Processing Record 45 of Set 8 | pevek
# Processing Record 46 of Set 8 | san lorenzo
# Processing Record 47 of Set 8 | kavaratti
# Processing Record 48 of Set 8 | huangpi
# Processing Record 49 of Set 8 | khristoforovo
# City not found. Skipping...
# Processing Record 50 of Set 8 | sabang
# Processing Record 1 of Set 9 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 2 of Set 9 | anloga
# Processing Record 3 of Set 9 | ayorou
# Processing Record 4 of Set 9 | coulihaut
# City not found. Skipping...
# Processing Record 5 of Set 9 | varadero
# Processing Record 6 of Set 9 | the valley
# Processing Record 7 of Set 9 | aksarka
# Processing Record 8 of Set 9 | bengkulu
# Processing Record 9 of Set 9 | andenes
# Processing Record 10 of Set 9 | kuah
# Processing Record 11 of Set 9 | angoche
# Processing Record 12 of Set 9 | praia da vitoria
# Processing Record 13 of Set 9 | longyearbyen
# Processing Record 14 of Set 9 | kholm
# Processing Record 15 of Set 9 | reyes
# Processing Record 16 of Set 9 | banapur
# Processing Record 17 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 18 of Set 9 | lata
# Processing Record 19 of Set 9 | tete
# Processing Record 20 of Set 9 | faya
# Processing Record 21 of Set 9 | lagoa
# Processing Record 22 of Set 9 | katangli
# Processing Record 23 of Set 9 | astoria
# Processing Record 24 of Set 9 | rafai
# Processing Record 25 of Set 9 | atambua
# Processing Record 26 of Set 9 | diban
# Processing Record 27 of Set 9 | sarh
# Processing Record 28 of Set 9 | acarau
# Processing Record 29 of Set 9 | tessalit
# Processing Record 30 of Set 9 | labuhan
# Processing Record 31 of Set 9 | adrar
# Processing Record 32 of Set 9 | camopi
# Processing Record 33 of Set 9 | carroll
# Processing Record 34 of Set 9 | urusha
# Processing Record 35 of Set 9 | kendari
# Processing Record 36 of Set 9 | rio grande
# Processing Record 37 of Set 9 | lokhvytsya
# Processing Record 38 of Set 9 | diapaga
# Processing Record 39 of Set 9 | kortenberg
# Processing Record 40 of Set 9 | sakaiminato
# Processing Record 41 of Set 9 | arifwala
# Processing Record 42 of Set 9 | leningradskiy
# Processing Record 43 of Set 9 | bathurst
# Processing Record 44 of Set 9 | rognan
# Processing Record 45 of Set 9 | dehloran
# Processing Record 46 of Set 9 | suvorovo
# Processing Record 47 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 9 | aitape
# Processing Record 49 of Set 9 | manono
# Processing Record 50 of Set 9 | westport
# Processing Record 1 of Set 10 | livingstonia
# Processing Record 2 of Set 10 | nador
# Processing Record 3 of Set 10 | olafsvik
# Processing Record 4 of Set 10 | kasongo
# Processing Record 5 of Set 10 | devecser
# Processing Record 6 of Set 10 | nanakuli
# Processing Record 7 of Set 10 | schruns
# Processing Record 8 of Set 10 | fare
# Processing Record 9 of Set 10 | ukiah
# Processing Record 10 of Set 10 | pemangkat
# Processing Record 11 of Set 10 | tricase
# Processing Record 12 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 13 of Set 10 | amapa
# Processing Record 14 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 10 | krasnyy luch
# Processing Record 16 of Set 10 | coquimbo
# Processing Record 17 of Set 10 | tiznit
# Processing Record 18 of Set 10 | contai
# Processing Record 19 of Set 10 | muros
# Processing Record 20 of Set 10 | valday
# Processing Record 21 of Set 10 | nemuro
# Processing Record 22 of Set 10 | hasaki
# Processing Record 23 of Set 10 | manjacaze
# Processing Record 24 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 10 | berbera
# Processing Record 26 of Set 10 | zabol
# Processing Record 27 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 28 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 30 of Set 10 | mantua
# Processing Record 31 of Set 10 | anori
# Processing Record 32 of Set 10 | san juan
# Processing Record 33 of Set 10 | mwinilunga
# Processing Record 34 of Set 10 | bani
# Processing Record 35 of Set 10 | lhokseumawe
# Processing Record 36 of Set 10 | dasoguz
# Processing Record 37 of Set 10 | diego de almagro
# Processing Record 38 of Set 10 | khadzhalmakhi
# Processing Record 39 of Set 10 | beloha
# Processing Record 40 of Set 10 | coihaique
# Processing Record 41 of Set 10 | saint-francois
# Processing Record 42 of Set 10 | kalianget
# Processing Record 43 of Set 10 | aklavik
# Processing Record 44 of Set 10 | alikalia
# Processing Record 45 of Set 10 | husavik
# Processing Record 46 of Set 10 | vastervik
# City not found. Skipping...
# Processing Record 47 of Set 10 | lamar
# Processing Record 48 of Set 10 | altay
# Processing Record 49 of Set 10 | malatya
# Processing Record 50 of Set 10 | zhangye
# Processing Record 1 of Set 11 | sambava
# Processing Record 2 of Set 11 | bousso
# Processing Record 3 of Set 11 | acari
# Processing Record 4 of Set 11 | walvis bay
# Processing Record 5 of Set 11 | saint-augustin
# Processing Record 6 of Set 11 | roald
# Processing Record 7 of Set 11 | lerwick
# Processing Record 8 of Set 11 | lomovka
# Processing Record 9 of Set 11 | dhidhdhoo
# Processing Record 10 of Set 11 | shibarghan
# City not found. Skipping...
# Processing Record 11 of Set 11 | visnes
# Processing Record 12 of Set 11 | batemans bay
# Processing Record 13 of Set 11 | vostok
# Processing Record 14 of Set 11 | saurimo
# Processing Record 15 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 11 | talaya
# Processing Record 17 of Set 11 | talcahuano
# Processing Record 18 of Set 11 | hamilton
# Processing Record 19 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 11 | kirkenaer
# Processing Record 21 of Set 11 | pattani
# Processing Record 22 of Set 11 | kalmunai
# Processing Record 23 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 11 | pacifica
# Processing Record 25 of Set 11 | dudinka
# Processing Record 26 of Set 11 | santa isabel do rio negro
# Processing Record 27 of Set 11 | serrai
# City not found. Skipping...
# Processing Record 28 of Set 11 | hervey bay
# Processing Record 29 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 11 | nichinan
# Processing Record 31 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 11 | itaqui
# Processing Record 33 of Set 11 | riaba
# City not found. Skipping...
# Processing Record 34 of Set 11 | toulepleu
# City not found. Skipping...
# Processing Record 35 of Set 11 | mudgee
# Processing Record 36 of Set 11 | santa lucia
# Processing Record 37 of Set 11 | telimele
# Processing Record 38 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 39 of Set 11 | feijo
# Processing Record 40 of Set 11 | port augusta
# Processing Record 41 of Set 11 | tura
# Processing Record 42 of Set 11 | salalah
# Processing Record 43 of Set 11 | khambhat
# Processing Record 44 of Set 11 | pingliang
# Processing Record 45 of Set 11 | mujiayingzi
# Processing Record 46 of Set 11 | kjollefjord
# Processing Record 47 of Set 11 | mikhaylovskoye
# Processing Record 48 of Set 11 | rocha
# Processing Record 49 of Set 11 | alta floresta
# Processing Record 50 of Set 11 | buchanan
# Processing Record 1 of Set 12 | sao gabriel da cachoeira
# Processing Record 2 of Set 12 | nagram
# Processing Record 3 of Set 12 | khani
# Processing Record 4 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 12 | butembo
# Processing Record 6 of Set 12 | port lincoln
# Processing Record 7 of Set 12 | kathu
# Processing Record 8 of Set 12 | alekseyevka
# Processing Record 9 of Set 12 | hammerfest
# Processing Record 10 of Set 12 | cortez
# Processing Record 11 of Set 12 | ornskoldsvik
# Processing Record 12 of Set 12 | makakilo city
# Processing Record 13 of Set 12 | mikuni
# Processing Record 14 of Set 12 | mende
# Processing Record 15 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 12 | marawi
# Processing Record 17 of Set 12 | trinidad
# Processing Record 18 of Set 12 | uvalde
# Processing Record 19 of Set 12 | goma
# Processing Record 20 of Set 12 | matamoros
# Processing Record 21 of Set 12 | anse-bertrand
# Processing Record 22 of Set 12 | senneterre
# Processing Record 23 of Set 12 | ko samui
# Processing Record 24 of Set 12 | torre del campo
# Processing Record 25 of Set 12 | pumiao
# Processing Record 26 of Set 12 | lincoln
# Processing Record 27 of Set 12 | jizan
# Processing Record 28 of Set 12 | tilichiki
# Processing Record 29 of Set 12 | boyuibe
# Processing Record 30 of Set 12 | winslow
# Processing Record 31 of Set 12 | iquitos
# Processing Record 32 of Set 12 | ruteng
# Processing Record 33 of Set 12 | flinders
# Processing Record 34 of Set 12 | meulaboh
# Processing Record 35 of Set 12 | curup
# Processing Record 36 of Set 12 | vila do maio
# Processing Record 37 of Set 12 | san ramon
# Processing Record 38 of Set 12 | chimbote
# Processing Record 39 of Set 12 | balkanabat
# Processing Record 40 of Set 12 | bo
# City not found. Skipping...
# Processing Record 41 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 12 | auki
# Processing Record 43 of Set 12 | dunedin
# Processing Record 44 of Set 12 | paraiso
# Processing Record 45 of Set 12 | pasni
# Processing Record 46 of Set 12 | naze
# Processing Record 47 of Set 12 | krivosheino
# Processing Record 48 of Set 12 | wakkanai
# Processing Record 49 of Set 12 | oktyabrskiy
# Processing Record 50 of Set 12 | knokke-heist
# Processing Record 1 of Set 13 | lukow
# Processing Record 2 of Set 13 | hailar
# Processing Record 3 of Set 13 | gorkovskoye
# City not found. Skipping...
# Processing Record 4 of Set 13 | zhezkazgan
# Processing Record 5 of Set 13 | shirokiy
# Processing Record 6 of Set 13 | diepholz
# Processing Record 7 of Set 13 | itacare
# Processing Record 8 of Set 13 | rio gallegos
# City not found. Skipping...
# Processing Record 9 of Set 13 | aquiraz
# City not found. Skipping...
# Processing Record 10 of Set 13 | komsomolskiy
# City not found. Skipping...
# Processing Record 11 of Set 13 | haines junction
# City not found. Skipping...
# Processing Record 12 of Set 13 | taltal
# City not found. Skipping...
# Processing Record 13 of Set 13 | saqqez
# City not found. Skipping...
# Processing Record 14 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 13 | podgornoye
# Processing Record 16 of Set 13 | kudahuvadhoo
# Processing Record 17 of Set 13 | borlange
# City not found. Skipping...
# Processing Record 18 of Set 13 | palu
# Processing Record 19 of Set 13 | taoudenni
# Processing Record 20 of Set 13 | asyut
# Processing Record 21 of Set 13 | mahajanga
# Processing Record 22 of Set 13 | barinas
# Processing Record 23 of Set 13 | liaocheng
# Processing Record 24 of Set 13 | halifax
# Processing Record 25 of Set 13 | asau
# Processing Record 26 of Set 13 | gusinoye ozero
# Processing Record 27 of Set 13 | mount isa
# Processing Record 28 of Set 13 | kushiro
# Processing Record 29 of Set 13 | malanje
# Processing Record 30 of Set 13 | boissevain
# Processing Record 31 of Set 13 | dargaville
# Processing Record 32 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 33 of Set 13 | la ronge
# Processing Record 34 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 35 of Set 13 | montepuez
# Processing Record 36 of Set 13 | gamba
# Processing Record 37 of Set 13 | iquique
# Processing Record 38 of Set 13 | jiuquan
# Processing Record 39 of Set 13 | domoni
# Processing Record 40 of Set 13 | zhengjiatun
# Processing Record 41 of Set 13 | constantine
# Processing Record 42 of Set 13 | afua
# Processing Record 43 of Set 13 | caucaia
# Processing Record 44 of Set 13 | erenhot
# Processing Record 45 of Set 13 | trat
# Processing Record 46 of Set 13 | belyy yar
# Processing Record 47 of Set 13 | porto novo
# Processing Record 48 of Set 13 | nueva guinea
# Processing Record 49 of Set 13 | balkhash
# Processing Record 50 of Set 13 | bella union
# Processing Record 1 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 2 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 14 | palauig
# Processing Record 4 of Set 14 | tena
# Processing Record 5 of Set 14 | medea
# Processing Record 6 of Set 14 | saint-ambroise
# Processing Record 7 of Set 14 | perth
# Processing Record 8 of Set 14 | kyzyl-suu
# Processing Record 9 of Set 14 | zabalj
# Processing Record 10 of Set 14 | calais
# Processing Record 11 of Set 14 | mercedes
# Processing Record 12 of Set 14 | burns lake
# Processing Record 13 of Set 14 | nishihara
# Processing Record 14 of Set 14 | eureka
# Processing Record 15 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 14 | cockburn town
# Processing Record 17 of Set 14 | pula
# Processing Record 18 of Set 14 | manicore
# Processing Record 19 of Set 14 | filadelfia
# Processing Record 20 of Set 14 | lakhi
# Processing Record 21 of Set 14 | traiguen
# Processing Record 22 of Set 14 | shitanjing
# Processing Record 23 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 24 of Set 14 | baker city
# Processing Record 25 of Set 14 | yumen
# Processing Record 26 of Set 14 | calceta
# Processing Record 27 of Set 14 | misratah
# Processing Record 28 of Set 14 | pokaran
# Processing Record 29 of Set 14 | bijar
# Processing Record 30 of Set 14 | weinan
# Processing Record 31 of Set 14 | turayf
# Processing Record 32 of Set 14 | turukhansk
# Processing Record 33 of Set 14 | pangnirtung
# Processing Record 34 of Set 14 | islamkot
# Processing Record 35 of Set 14 | elbistan
# Processing Record 36 of Set 14 | gushikawa
# Processing Record 37 of Set 14 | yeppoon
# Processing Record 38 of Set 14 | chicama
# Processing Record 39 of Set 14 | gat
# Processing Record 40 of Set 14 | saint-georges
# Processing Record 41 of Set 14 | rehoboth
# Processing Record 42 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 43 of Set 14 | yushala
# Processing Record 44 of Set 14 | palo alto
# Processing Record 45 of Set 14 | buala
# Processing Record 46 of Set 14 | teknaf
# Processing Record 47 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 14 | shache
# Processing Record 49 of Set 14 | korla
# Processing Record 50 of Set 14 | ankola
# Processing Record 1 of Set 15 | omsukchan
# Processing Record 2 of Set 15 | florencia
# Processing Record 3 of Set 15 | safford
# Processing Record 4 of Set 15 | flin flon
# Processing Record 5 of Set 15 | dmytrivka
# Processing Record 6 of Set 15 | veles
# Processing Record 7 of Set 15 | sola
# Processing Record 8 of Set 15 | placido de castro
# Processing Record 9 of Set 15 | la libertad
# Processing Record 10 of Set 15 | soyo
# Processing Record 11 of Set 15 | sibolga
# Processing Record 12 of Set 15 | kanniyakumari
# Processing Record 13 of Set 15 | garissa
# Processing Record 14 of Set 15 | yulara
# Processing Record 15 of Set 15 | road town
# Processing Record 16 of Set 15 | port hedland
# Processing Record 17 of Set 15 | mananjary
# Processing Record 18 of Set 15 | candawaga
# City not found. Skipping...
# Processing Record 19 of Set 15 | merauke
# Processing Record 20 of Set 15 | storsteinnes
# Processing Record 21 of Set 15 | mutoko
# Processing Record 22 of Set 15 | itaporanga
# Processing Record 23 of Set 15 | krasnokholmskiy
# Processing Record 24 of Set 15 | north bend
# Processing Record 25 of Set 15 | moyale
# Processing Record 26 of Set 15 | kodino
# Processing Record 27 of Set 15 | stuttgart
# Processing Record 28 of Set 15 | nenjiang
# Processing Record 29 of Set 15 | dali
# Processing Record 30 of Set 15 | adre
# Processing Record 31 of Set 15 | berdigestyakh
# Processing Record 32 of Set 15 | mangai
# Processing Record 33 of Set 15 | dickinson
# Processing Record 34 of Set 15 | duldurga
# Processing Record 35 of Set 15 | daxian
# City not found. Skipping...
# Processing Record 36 of Set 15 | manaure
# Processing Record 37 of Set 15 | makueni
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 663

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Cape Town -33.9258   18.4232     66.88        82          40
# 1  Ponta Do Sol  32.6667  -17.1000     67.01        83           2
# 2         Vaini -21.2000 -175.2000     78.96        89          40
# 3     Biskamzha  53.4497   89.5272    -15.32       100          85
# 4          Chuy -33.6971  -53.4616     76.15        61         100
# 5   Bonaventure  48.0457  -65.4926     30.78        80         100
# 6     Busselton -33.6500  115.3333     55.74        75           4
# 7       Ushuaia -54.8000  -68.3000     51.46        50          40
# 8         Turka  49.1541   23.0297     37.80        98         100
# 9  Constitucion -35.3333  -72.4167     66.61        52           0
#
#    Wind Speed Country Current Description
# 0        4.61      ZA    scattered clouds
# 1        5.35      PT           clear sky
# 2        8.05      TO    scattered clouds
# 3        0.96      RU     overcast clouds
# 4       15.55      UY     overcast clouds
# 5       14.97      CA                snow
# 6        8.63      AU           clear sky
# 7       28.77      AR    scattered clouds
# 8        6.42      UA     overcast clouds
# 9       22.41      CL           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 
                    'Cloudiness', 'Wind Speed', 'Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Cape Town      ZA -33.9258   18.4232     66.88        82          40
# 1  Ponta Do Sol      PT  32.6667  -17.1000     67.01        83           2
# 2         Vaini      TO -21.2000 -175.2000     78.96        89          40
# 3     Biskamzha      RU  53.4497   89.5272    -15.32       100          85
# 4          Chuy      UY -33.6971  -53.4616     76.15        61         100
# 5   Bonaventure      CA  48.0457  -65.4926     30.78        80         100
# 6     Busselton      AU -33.6500  115.3333     55.74        75           4
# 7       Ushuaia      AR -54.8000  -68.3000     51.46        50          40
# 8         Turka      UA  49.1541   23.0297     37.80        98         100
# 9  Constitucion      CL -35.3333  -72.4167     66.61        52           0
#
#    Wind Speed Current Description
# 0        4.61    scattered clouds
# 1        5.35           clear sky
# 2        8.05    scattered clouds
# 3        0.96     overcast clouds
# 4       15.55     overcast clouds
# 5       14.97                snow
# 6        8.63           clear sky
# 7       28.77    scattered clouds
# 8        6.42     overcast clouds
# 9       22.41           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = 'Weatherpy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file, index_label='City_ID')
